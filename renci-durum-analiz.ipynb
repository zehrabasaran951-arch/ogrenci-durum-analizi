# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/students-csv/students.csv")
print(df)
df["ortalama"] = df["vize"] * 0.40 + df["final"] * 0.60
import numpy as np
df["basari"]= np.where(
  df["ortalama"] >=60,
 "basarili",
 "basarisiz"
)
df["risk"] = np.where(df["devamsizlik"] > 4, "riskli", "risksiz")

df.head()
# Out:
#             isim  vize  final  devamsizlik
# 0  Mercan yilmaz    89     95            1
# 1      Bulut can    55     65            3
# 2   Recep özmert    45     88            4
# 3  Zeynep kacgin    59     77            2
# 4     Ahmet neşe    68     74            5
#             isim  vize  final  devamsizlik  ortalama    basari     risk
# 0  Mercan yilmaz    89     95            1      92.6  basarili  risksiz
# 1      Bulut can    55     65            3      61.0  basarili  risksiz
# 2   Recep özmert    45     88            4      70.8  basarili  risksiz
# 3  Zeynep kacgin    59     77            2      69.8  basarili  risksiz
# 4     Ahmet neşe    68     74            5      71.6  basarili   riskli

# %%
import os
os.listdir("/kaggle/input/students-csv")
# Out:
# ['students.csv']

# %%
df[["  isim", "ortalama", "basari"]]
# Out:
#             isim  ortalama    basari
# 0  Mercan yilmaz      92.6  basarili
# 1      Bulut can      61.0  basarili
# 2   Recep özmert      70.8  basarili
# 3  Zeynep kacgin      69.8  basarili
# 4     Ahmet neşe      71.6  basarili

# %%
df.columns
# Out:
# Index(['  isim', 'vize', 'final', 'devamsizlik', 'ortalama', 'basari'], dtype='object')
